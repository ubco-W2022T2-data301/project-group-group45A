# %% [markdown]
# # Evelyn Pu

# %% [markdown]
# ## Research question/interests(written in PM2)
#
#
#
# My personal interest is to analyze the user profile statistics of bike-sharing. My analysis might include the ***usage preferences of each of these two types of users ( casual and registered) in different situations***(e.g., in different weather, on weekends or weekdays of the week), as well as analyzing their respective percentages of total users.
#
#
# To figure out this, I might analyze：
#
#
# 1. what are the usage habits of these two types of users in different weather? For example, analyze the relationship between the number of humidity, temperature, and wind speed and the two types of users in casual and registered to determine how they have usage preferences for bike-sharing in different weather.
# Possible details include (1) using seaborn to plot humidity, temperature, and wind speed as histograms or line graphs (2) plotting the number of casual and registered users as line graphs (3) combining the graphs in (1) (2) to see if they have a positive association with each other.
# 2. What are the usage preferences of these two users for each day of the week? For example, do they prefer to use bike-sharing on weekends?
# Possible details include: (1) read the dataset from the day.csv file, count the columns = weekday with value= 0,6 as weekend and 1,2,3,4,5 as weekday,and calculate two types of user numbers when the weekday value = 1,2,3,4,5,6,0(2) Plot the histogram, the ideal output should be a histogram with x-axis values 0,1,2,3,4,5,6 and split with casual and registered. (3) Observe: whether there are always more (or less) users of both types when weekday=0,6.
#
# 3. For both types of users, is there always more users of one type? -I want to compare the respective values, using an int variable or a bool variable to record the number of times the number of users of one type is greater than the number of users of the other type, and if so, the number is added to 1 or defined as true. (But I'm not sure which is better and will try it in a later analysis.) Possible details include. (1) Assume an int variable named x that records the number of times one class of users has more users than another. (2) Add a column named 'IFregMORE', of type boolean. (3) Combine the while/for Loop and if statements to determine true when there are more users in one class than in another, and apply this condition to each line of the loop. (4) At the end of the loop, use count() to calculate the number of times true and assign it to x to determine if there are always more users in one class than in another. (5) (Optional) Calculate statistics for both categories of users, such as mean, median, minimum and maximum, etc., to plot box plots.

# %%
#Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns

# %%
day = pd.read_csv("../data/raw/day.csv")
day
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
day_clean=day.drop(['instant','yr','weathersit',],axis=1)
day_clean.head()
# Out:
#        dteday  season  mnth  holiday  weekday  workingday      temp     atemp  \
# 0  2011-01-01       1     1        0        6           0  0.344167  0.363625
# 1  2011-01-02       1     1        0        0           0  0.363478  0.353739
# 2  2011-01-03       1     1        0        1           1  0.196364  0.189405
# 3  2011-01-04       1     1        0        2           1  0.200000  0.212122
# 4  2011-01-05       1     1        0        3           1  0.226957  0.229270
#
#         hum  windspeed  casual  registered   cnt
# 0  0.805833   0.160446     331         654   985
# 1  0.696087   0.248539     131         670   801
# 2  0.437273   0.248309     120        1229  1349
# 3  0.590435   0.160296     108        1454  1562
# 4  0.436957   0.186900      82        1518  1600

# %%
day_clean.columns
# Out:
# Index(['dteday', 'season', 'mnth', 'holiday', 'weekday', 'workingday', 'temp',
#        'atemp', 'hum', 'windspeed', 'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
day_clean.describe()
# Out:
#            season        mnth     holiday     weekday  workingday        temp  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     2.496580    6.519836    0.028728    2.997264    0.683995    0.495385
# std      1.110807    3.451913    0.167155    2.004787    0.465233    0.183051
# min      1.000000    1.000000    0.000000    0.000000    0.000000    0.059130
# 25%      2.000000    4.000000    0.000000    1.000000    0.000000    0.337083
# 50%      3.000000    7.000000    0.000000    3.000000    1.000000    0.498333
# 75%      3.000000   10.000000    0.000000    5.000000    1.000000    0.655417
# max      4.000000   12.000000    1.000000    6.000000    1.000000    0.861667
#
#             atemp         hum   windspeed       casual   registered  \
# count  731.000000  731.000000  731.000000   731.000000   731.000000
# mean     0.474354    0.627894    0.190486   848.176471  3656.172367
# ...

# %% [markdown]
# ### EDA - initial thoughts
#
# 1. From the observations obtained by describe(), the statistics of registered users are always more than those of casual users.
# Is this always the case on every day?
#
# 2. Temperature/humidity/windspeed changes every day, do they effect on users?
#
# 3. A day can be defined as weekday or not and holiday or not.

# %% [markdown]
# ### EDA - Reasearch Questions
# 1. Are there always more registered users than casual users?
# 2. Do changes in humidity/temperature/windspeed have an effect on the number of users?
# 3. Does a holiday or non-holiday, weekend or weekday have an impact on the number of users?

# %%
# Data analysis and visualization for RQ1
total_registered = day_clean['registered'].sum()
total_casual = day_clean['casual'].sum()

# Create a DataFrame for the data
df = pd.DataFrame({'type': ['registered', 'casual'], 'count': [total_registered, total_casual]})

# Create the bar plot
sns.barplot(x='type', y='count', data=df)
# Out:
# <AxesSubplot: xlabel='type', ylabel='count'>

# %%
# Data analysis and visualization for RQ1
daily_counts = day_clean.groupby('dteday')[['registered', 'casual']].sum()

# Reset the index to make the date a column
daily_counts = daily_counts.reset_index()

# Melt the data to create a "long" format with separate columns for the user types
daily_counts_long = pd.melt(daily_counts, id_vars=['dteday'], value_vars=['registered', 'casual'], var_name='type', value_name='count')

# Create the line plot
sns.lineplot(x='dteday', y='count', hue='type', data=daily_counts_long)
# Out:
# <AxesSubplot: xlabel='dteday', ylabel='count'>

# %%
# Data analysis and visualization for RQ2

# I creat a scatterplot to show that if there is any relation between temperature and user's numbers.
sns.scatterplot(x='temp', y='cnt', data=day_clean)
# Out:
# <AxesSubplot: xlabel='temp', ylabel='cnt'>

# %%
# Data analysis and visualization for RQ3


# Create bar plot of average number of users on holidays vs. non-holidays
sns.barplot(x='holiday', y='cnt', data=day_clean)

# Create bar plot of average number of users on weekends vs. weekdays
sns.barplot(x='weekday', y='cnt', data=day_clean)
# Out:
# <AxesSubplot: xlabel='weekday', ylabel='cnt'>

# %%
# Data analysis and visualization for RQ3

# Create bar plot of average number of users on holidays vs. non-holidays
sns.barplot(x='holiday', y='cnt', data=day_clean)
# Out:
# <AxesSubplot: xlabel='holiday', ylabel='cnt'>

# %%
# Data analysis and visualization for RQ3

# Create box plot of number of users by holiday
sns.boxplot(x='holiday', y='cnt', data=day_clean)
# Out:
# <AxesSubplot: xlabel='holiday', ylabel='cnt'>

# %% [markdown]
# ### EDA - Summary and conclusions
# 1. From the total number of both types of users, registered users are much larger than casual users; from the data of each day, registered users are always more than casual users
#
# 2. The temperature is positively associated with the total number of users, the higher the temperature, the greater the proportion of more users, but after the temperature reaches 0.6, it starts to become an inverse association.
#
# 3. There is no correlation between the number of users and the day of the week.
#
# 4. There is a connection between the number of users and whether it is a holiday or not, and the number of users is more when it is not a holiday

# %% [markdown]
# ## Refine your research questions(written in PM3)
#
#
# Through EDA, I found that the two questions of which type of users are more numerous and whether users are affected by weekdays or non-working days have been solved. But other issues need to continue to be studied.
#
# My main research questions are ***the characteristics of two types of users using bike-sharing in different environments, i.e., how they are affected by weather (temperature/humidity/wind speed), and by holidays, respectively.***
#
#
# To figure out this, I might analyze：
# #### 1. Is the number of users affected by humidity? Is it affected by wind speed?
#
# - Just like the EDA analysis in PM3, I will create a scatterplot to show whether humidity and wind speed are correlated with the number of users.
#
# #### 2. How are the two types of users, casual and registered, affected by weather conditions, respectively? What are their characteristics? Are the values positively or negatively correlated?
#
#  - Convert the "dteday" column to a datetime format
#
# - Check for missing or null values and handle them appropriately
#
#
#  - Create scatter plots and heatmaps to visualize the relationship between temperature, humidity, windspeed, and the number of registered and casual users
#
# - Calculate correlation coefficients to measure the strength of the relationship between these variables
#
#  - Aggregate the data by weather condition and calculate summary statistics for the number of registered and casual users (e.g., mean, median, standard deviation)
#
#  - Create box plots to visualize the distribution of the number of users for each weather condition and each user type
#
# #### 3. How are the two types of users affected by holidays? Do they both prefer non-holiday use of bicycle sharing?
#
#   - check if there are any missing values in dataset
#
#   - group the data by the holiday column and calculate the mean of the casual and registered columns separately for each group.
#
#   - use a bar plot or box plot to visualize the average number of casual and registered users on holidays and non-holidays.
