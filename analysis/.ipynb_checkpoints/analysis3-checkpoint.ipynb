# %% [markdown]
# # Evelyn Pu

# %% [markdown]
# My research question is to find the conditional preferences of two categories of users, CASUAL, REGISTERED, and all users (that is, the sum of these two categories) in using bike-sharing, and to analyze how weather conditions affect their preferences in terms of humidity, wind speed, and temperature.

# %%
#Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns

# %%
day = pd.read_csv("../data/raw/day.csv")
day
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
hour= pd.read_csv("../data/raw/hour.csv")
hour
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01       1   0     1   0        0        6
# 1            2  2011-01-01       1   0     1   1        0        6
# 2            3  2011-01-01       1   0     1   2        0        6
# 3            4  2011-01-01       1   0     1   3        0        6
# 4            5  2011-01-01       1   0     1   4        0        6
# ...        ...         ...     ...  ..   ...  ..      ...      ...
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 0               0           1  0.24  0.2879  0.81     0.0000       3
# ...

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# After looking at my dataset, I decided to just use the day.csv file because it contained the information I needed, including weather information and the number of users in different types. There was no need to use any other dataset.

# %%
path0="../data/raw/day.csv"
day= pd.read_csv(path0)
day.info
# Out:
# <bound method DataFrame.info of      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
# ...

# %%
day.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
day.tail()
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 726           2  0.254167  0.226642  0.652917   0.350133     247        1867
# 727           2  0.253333  0.255046  0.590000   0.155471     644        2451
# 728           2  0.253333  0.242400  0.752917   0.124383     159        1182
# 729           1  0.255833  0.231700  0.483333   0.350754     364        1432
# 730           2  0.215833  0.223487  0.577500   0.154846     439        2290
#
#       cnt
# 726  2114
# 727  3095
# 728  1341
# 729  1796
# ...

# %%
day.shape
# Out:
# (731, 16)

# %%
day.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %%
day.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
# I am going to cleaning my dataset.

# %%
day.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# **There was some data in the dataset that I didn't need, and now I am going to edit the dataset to make it fit my research question**

# %%
perfect=day.drop(['instant','dteday','yr','season','mnth','holiday','workingday','weekday','atemp'],axis=1)
perfect
# Out:
#      weathersit      temp       hum  windspeed  casual  registered   cnt
# 0             2  0.344167  0.805833   0.160446     331         654   985
# 1             2  0.363478  0.696087   0.248539     131         670   801
# 2             1  0.196364  0.437273   0.248309     120        1229  1349
# 3             1  0.200000  0.590435   0.160296     108        1454  1562
# 4             1  0.226957  0.436957   0.186900      82        1518  1600
# ..          ...       ...       ...        ...     ...         ...   ...
# 726           2  0.254167  0.652917   0.350133     247        1867  2114
# 727           2  0.253333  0.590000   0.155471     644        2451  3095
# 728           2  0.253333  0.752917   0.124383     159        1182  1341
# 729           1  0.255833  0.483333   0.350754     364        1432  1796
# 730           2  0.215833  0.577500   0.154846     439        2290  2729
#
# [731 rows x 7 columns]

# %%
perfect.describe()
# Out:
#        weathersit        temp         hum   windspeed       casual  \
# count  731.000000  731.000000  731.000000  731.000000   731.000000
# mean     1.395349    0.495385    0.627894    0.190486   848.176471
# std      0.544894    0.183051    0.142429    0.077498   686.622488
# min      1.000000    0.059130    0.000000    0.022392     2.000000
# 25%      1.000000    0.337083    0.520000    0.134950   315.500000
# 50%      1.000000    0.498333    0.626667    0.180975   713.000000
# 75%      2.000000    0.655417    0.730209    0.233214  1096.000000
# max      3.000000    0.861667    0.972500    0.507463  3410.000000
#
#         registered          cnt
# count   731.000000   731.000000
# mean   3656.172367  4504.348837
# std    1560.256377  1937.211452
# min      20.000000    22.000000
# 25%    2497.000000  3152.000000
# 50%    3662.000000  4548.000000
# 75%    4776.500000  5956.000000
# max    6946.000000  8714.000000

# %%
#relationship analysis
relationship= perfect.corr()
relationship
# Out:
#             weathersit      temp       hum  windspeed    casual  registered  \
# weathersit    1.000000 -0.120602  0.591045   0.039511 -0.247353   -0.260388
# temp         -0.120602  1.000000  0.126963  -0.157944  0.543285    0.540012
# hum           0.591045  0.126963  1.000000  -0.248489 -0.077008   -0.091089
# windspeed     0.039511 -0.157944 -0.248489   1.000000 -0.167613   -0.217449
# casual       -0.247353  0.543285 -0.077008  -0.167613  1.000000    0.395282
# registered   -0.260388  0.540012 -0.091089  -0.217449  0.395282    1.000000
# cnt          -0.297391  0.627494 -0.100659  -0.234545  0.672804    0.945517
#
#                  cnt
# weathersit -0.297391
# temp        0.627494
# hum        -0.100659
# windspeed  -0.234545
# casual      0.672804
# registered  0.945517
# cnt         1.000000

# %%
sns.heatmap(relationship, xticklabels=relationship.columns, yticklabels=relationship.columns, annot=True)
plt.title('Correlation between the variables')
#TRYING TO SEE ALL THE VARIABLES TOGETHER TO TRY AND NOTICE ANY RLATIONSHIPS
# Out:
# Text(0.5, 1.0, 'Correlation between the variables')

# %% [markdown]
# Here, we can see that:
# The users of rental bikes consist mainly of registered users,
# and the number of users is positively related to temperature and inversely proportional to humidity and wind speed

# %%
sns.pairplot(perfect, x_vars =["temp", "hum", "windspeed","weathersit"], y_vars = ["casual", "registered", "cnt"])
plt.suptitle('Different groups of users in weather conditions ',y=1.05, fontsize=16)
# Out:
# Text(0.5, 1.05, 'Different groups of users in weather conditions ')

# %% [markdown]
# ## Research Answer

# %% [markdown]
# Now, I'm going to use the dataset and perform a visualization analysis to answer my research question

# %%
#loading dataset after applied function
df
# Out:
#      weathercondition      temp       hum  windspeed  casual  registered  \
# 0                   2  0.344167  0.805833   0.160446     331         654
# 1                   2  0.363478  0.696087   0.248539     131         670
# 2                   1  0.200000  0.590435   0.160296     108        1454
# 3                   2  0.169091  0.686364   0.122132      43        1220
# 4                   1  0.160870  0.537826   0.126548      54        1367
# ..                ...       ...       ...        ...     ...         ...
# 435                 1  0.245833  0.515417   0.133083     408        1379
# 436                 2  0.291304  0.734783   0.168726     440         573
# 437                 2  0.253333  0.590000   0.155471     644        2451
# 438                 2  0.253333  0.752917   0.124383     159        1182
# 439                 2  0.215833  0.577500   0.154846     439        2290
#
#      total users  rainy_day
# 0            985          1
# 1            801          0
# ...

# %% [markdown]
# from the source: https://business-science.github.io/timetk/reference/bike_sharing_daily.html
#
# I can know that the 'weathersit' column represents:
#
#     1: Clear, Few clouds, Partly cloudy, Partly cloudy
#
#     2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
#
#     3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
#
#     4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog

# %%
relationship = df.corr()
sns.heatmap(relationship, xticklabels=relationship.columns, yticklabels=relationship.columns, annot=True)
plt.title('Correlation between the variables',y=1.05,fontsize=16)
# Out:
# Text(0.5, 1.05, 'Correlation between the variables')

# %%
sns.pairplot(df, x_vars =["windspeed", "rainy_day", "temp" ], y_vars = ["casual"])
plt.title('Casual users in different windspeed, temperature and rainy day')
# Out:
# Text(0.5, 1.0, 'Casual users in different windspeed, temperature and rainy day')

# %% [markdown]
# **As can be seen from the graph, in terms of casual users, people prefer to travel on non-rainy days when the temperature is higher, but at the same time prefer low wind speed.**

# %%
sns.pairplot(df, x_vars =["windspeed", "rainy_day", "temp" ], y_vars = ["registered"])
plt.title('Registered users in different windspeed, temperature and rainy day')
# Out:
# Text(0.5, 1.0, 'Registered users in different windspeed, temperature and rainy day')

# %% [markdown]
# **As can be seen from the graph, in terms of registered users, people prefer to travel on non-rainy days when the temperature is higher and wind speed is not a determining factor.**

# %%
sns.pairplot(df, x_vars =["windspeed", "rainy_day", "temp" ], y_vars = ["total users"])
plt.title('Total users in different windspeed, temperature and rainy day')
# Out:
# Text(0.5, 1.0, 'Total users in different windspeed, temperature and rainy day')

# %% [markdown]
# **As can be seen from the graph, from all users, people prefer to travel on non-rainy days when the temperature is higher and wind speed is not a determining factor.This may be because registered users make up the majority of users and therefore influence the preference of total users.**

# %%
# Group by weather condition and calculate total users, casual users, and registered users
grouped = df.groupby("weathercondition").agg({"total users": "sum", "casual": "sum", "registered": "sum"}).reset_index()

# Melt the data to create a long-form dataset for plotting
melted = grouped.melt(id_vars=["weathercondition"], var_name="user_type", value_name="count")

# Create bar plot
sns.barplot(x="weathercondition", y="count", hue="user_type", data=melted)

# Add title and axis labels
plt.title("Distribution of User Types by Weather Condition")
plt.xlabel("Weather Condition")

# Show plot
plt.show()

# %% [markdown]
# **In terms of approximate weather conditions, all users prefer to use rental bikes in weather condition 1, followed by condition 2 and then condition 3. No one like to travel in weather condition 4.**

# %% [markdown]
# ### Conclusion

# %% [markdown]
# 1. For all types of users , their favorite weather condition is 1 which represents a clear, few clouds, or partly cloudy day. And then followed by 2 and then 3. No one travles in weather condition 4.
# 2. For all types of users , they prefer non-rainy days.
# 3. For all types of users , people prefer to travel when the temperature is higher.
# 4. For casual users ,they prefer lower wind speed.
# 5. For registered users, the wind speed is not a determining factor for their travel. This is also true for total users.This may be because registered users make up the majority of users and therefore influence the preference of total users.
